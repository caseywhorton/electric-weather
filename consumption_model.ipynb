# %%
import pandas as pd
import numpy as np
import json

# %%
f = open('electric_consumption.json')
data = json.load(f)

# %%
data = pd.json_normalize(data['response']['data'])

# %%
data[data.stateid == 'OH']
# Out:
#           period stateid stateDescription sectorid      sectorName  customers  \
# period
# 2023-05  2023-05      OH             Ohio      TRA  transportation        2.0
# 2023-05  2023-05      OH             Ohio      ALL     all sectors  5717247.0
# 2023-05  2023-05      OH             Ohio      RES     residential  5074075.0
# 2023-05  2023-05      OH             Ohio      OTH           other        NaN
# 2023-05  2023-05      OH             Ohio      IND      industrial    19285.0
# ...          ...     ...              ...      ...             ...        ...
# 2018-01  2018-01      OH             Ohio      IND      industrial    18820.0
# 2018-01  2018-01      OH             Ohio      RES     residential  4966286.0
# 2018-01  2018-01      OH             Ohio      TRA  transportation        2.0
# 2018-01  2018-01      OH             Ohio      ALL     all sectors  5615237.0
# 2018-01  2018-01      OH             Ohio      COM      commercial   630129.0
#
# ...

# %%
data.index = data.period
data_res = data[data.sectorid == 'RES']
data_res.sort_index(inplace=True)
# Out:
# /var/folders/dk/w25w7v256r15pk9pvk88_y780000gn/T/ipykernel_40243/2403980060.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_res.sort_index(inplace=True)

# %%
data_res.customers.plot()
# Out:
# <AxesSubplot: xlabel='period'>

# %%
data_res['sales'].plot()
# Out:
# <AxesSubplot: xlabel='period'>
